# %%
import pandas as pd
from pathlib import Path

# %%
#if file not found
if not Path('./capture20110810.binetflow').is_file():
    # !wget https://storage.googleapis.com/security-analytics-datasets-public/capture20110810.binetflow -O binetflow
# Out:
# --2022-02-18 18:23:05--  https://storage.googleapis.com/security-analytics-datasets-public/capture20110810.binetflow
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.72.80, 142.250.69.240, 142.250.72.16, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.72.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386629271 (369M) [application/octet-stream]
# Saving to: ‘binetflow’
#
# binetflow           100%[===================>] 368.72M  1.76MB/s    in 3m 53s
#
# 2022-02-18 18:26:58 (1.59 MB/s) - ‘binetflow’ saved [386629271/386629271]

# %%
if not Path('./capture20110810.binetflow').is_file():
    # !wget https://storage.googleapis.com/security-analytics-datasets-public/capture20110810.binetflow

# %%
df = pd.read_csv("binetflow")
df
# Out:
#                           StartTime          Dur Proto        SrcAddr  Sport  \
# 0        2011/08/10 09:46:53.047277  3550.182373   udp  212.50.71.179  39678
# 1        2011/08/10 09:46:53.048843     0.000883   udp  84.13.246.132  28431
# 2        2011/08/10 09:46:53.049895     0.000326   tcp  217.163.21.35     80
# 3        2011/08/10 09:46:53.053771     0.056966   tcp     83.3.77.74  32882
# 4        2011/08/10 09:46:53.053937  3427.768066   udp  74.89.223.204  21278
# ...                             ...          ...   ...            ...    ...
# 2824631  2011/08/10 15:54:07.352393     0.000393   udp   147.32.86.92  36363
# 2824632  2011/08/10 15:54:07.353854     0.000935   udp   58.165.41.84  60122
# 2824633  2011/08/10 15:54:07.357302     0.000000   tcp  147.32.84.171  47077
# 2824634  2011/08/10 15:54:07.366830     0.002618   udp    93.79.39.15  10520
# 2824635  2011/08/10 15:54:07.368340     0.001122   udp  78.56.231.126  29419
#
# ...

# %% [markdown]
# # Load the model
# # receive data for prediction
# # get a prediction
# # return it

# %%
from sklearn.linear

# %%
import pickle
s = pickle.dumps(clf)
s

# %%
the_model_string = b'\da'
import pickle

# %%
w
clf=pickle.loads(the_mode_string)

# %% [markdown]
# ``` python
# #check the hmac
#
# secret_key= '123'
# secret_key
# pickled_string = load_from_database()
# picked_string_hmac_hash = load_this_from_db()
# import md5 from hashlib
# hash = md5.get_hash(f'{secret_key}:{pickled_string}')
#
# def
# ```

# %%
from joblib import dump,load
with open('clf.pickle', 'wb') as f:
    pickle.dump(clf, f)

# %% [markdown]
# # API

# %% [markdown]
# ```
# . venv/bin/activate
#
# python3 -m venv venv
#
# pip install Flask
#
# flask run
#
# ```
