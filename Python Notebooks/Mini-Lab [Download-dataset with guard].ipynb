# %% [markdown]
# # Mini-Lab -- Download a Dataset, with Guards
#
# This mini-lab is a follow-up to some in-class activities we've done.
# It intentionally doesn't remind you explicitly how to do stuff, because
# part of the activity is to learn how to do these things on your own!
#
#
# ## Hints
#
# These google searches may help you:
#
# * `wget download as filename`
# * `python check if file exists`
# * `jupyter run shell command`
#
# ## Deliverable
#
# Complete the `load_ctu_13_scenario_13` function, fulfilling the requirements listed in its docstring.
#
# Submit a completed version of this notebook, in `.ipynb` format.

# %%
# Do python library imports...
import pandas as pd
from pathlib import Path

# %%
def load_ctu_13_scenario_13():
    if Path('./ctu-13-scenario-13.zip').is_file():
        print(f'ctu-13-scenario-13.zip already exists in local')
    else:
        # !wget https://storage.googleapis.com/security-analytics-datasets-public/ctu-13-scenario-13.zip
    
    if Path('./capture20110815-3.binetflow').is_file():
        print(f'capture20110815-3.binetflow already exists in local')
    else:
        # !unzip ctu-13-scenario-13.zip

    df = pd.read_csv("capture20110815-3.binetflow")
    return df

df = load_ctu_13_scenario_13()
# Out:
# /bin/bash: wget: command not found
# unzip:  cannot find or open ctu-13-scenario-13.zip, ctu-13-scenario-13.zip.zip or ctu-13-scenario-13.zip.ZIP.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/7m/7w9ylryx3v1chtz0tqvj85f40000gp/T/ipykernel_3138/2581511303.py in <module>
#      13     return df
#      14
# ---> 15 df = load_ctu_13_scenario_13()
#
# /var/folders/7m/7w9ylryx3v1chtz0tqvj85f40000gp/T/ipykernel_3138/2581511303.py in load_ctu_13_scenario_13()
#      10         get_ipython().system('unzip ctu-13-scenario-13.zip')
#      11
# ---> 12     df = pd.read_csv("capture20110815-3.binetflow")
#      13     return df
#      14
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
# ...

# %% [markdown]
# ## Peek at the dataframe...
#
# This is provided to show you what the data should look like once you have loaded it.

# %%
# https://stackoverflow.com/questions/48997644/how-to-describe-columns-as-categorical-values
df.astype('object').describe().transpose()
# Out:
#                count    unique                                     top  \
# StartTime    1925149   1925147              2011/08/16 03:02:32.189675
# Dur        1925149.0  658406.0                                     0.0
# Proto        1925149        15                                     udp
# SrcAddr      1925149    277486                           147.32.84.138
# Sport        1898868     64571                                   13363
# Dir          1925149         7                                     <->
# DstAddr      1925149     77330                             147.32.80.9
# Dport        1915024     51986                                      53
# State        1925148       235                                     CON
# sTos       1898070.0       5.0                                     0.0
# dTos       1803339.0       4.0                                     0.0
# TotPkts      1925149      2954                                       2
# ...
